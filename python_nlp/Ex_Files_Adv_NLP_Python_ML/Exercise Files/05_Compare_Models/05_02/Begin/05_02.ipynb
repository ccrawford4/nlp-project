# %% [markdown]
# # Compare NLP Techniques: Build Model On TF-IDF Vectors

# %% [markdown]
# ### Read In Cleaned Text

# %%
# Load the cleaned training and test sets
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

X_train = pd.read_csv('../../../data/X_train.csv')
X_test = pd.read_csv('../../../data/X_test.csv')
y_train = pd.read_csv('../../../data/y_train.csv')
y_test = pd.read_csv('../../../data/y_test.csv')

X_train.head()
# Out:
#                                           clean_text
# 0  ['brainless', 'baby', 'dolld', 'vehicle', 'sar...
# 1  ['nimbomsons', 'yep', 'phone', 'knows', 'one',...
# 2                     ['record', 'one', 'night', '']
# 3  ['went', 'attend', 'another', 'two', 'rounds',...
# 4  ['hi', 'juan', 'im', 'coming', 'home', 'fri', ...

# %% [markdown]
# ### Create TF-IDF Vectors

# %%
# Instantiate and fit a TFIDF vectorizer and then use that trained vectorizer
# to transform the messages in the training and test sets
tfidf_vect = TfidfVectorizer()
tfidf_vect.fit(X_train['clean_text'])
X_train_vect = tfidf_vect.transform(X_train['clean_text'])
X_test_vect = tfidf_vect.transform(X_test['clean_text'])

# %%
# What words did the vectorizer learn?
tfidf_vect.vocabulary_
# Out:
# {'brainless': 1540,
#  'baby': 1255,
#  'dolld': 2523,
#  'vehicle': 7678,
#  'sariyag': 6253,
#  'drive': 2577,
#  'madoke': 4538,
#  'barolla': 1297,
#  'nimbomsons': 5049,
#  'yep': 8153,
#  'phone': 5492,
#  'knows': 4175,
#  'one': 5236,
#  'obviously': 5176,
#  'cos': 2119,
#  'thats': 7207,
#  'real': 5928,
#  'word': 8000,
#  'record': 5966,
#  'night': 5041,
#  'went': 7873,
#  'attend': 1192,
#  'another': 1046,
#  'two': 7506,
#  'rounds': 6169,
#  'todaybut': 7339,
#  'still': 6864,
#  'didt': 2421,
#  'reach': 5916,
#  'home': 3640,
#  'hi': 3583,
#  'juan': 4056,
#  'im': 3790,
#  'coming': 2010,
#  'fri': 3133,
#  'hey': 3578,
#  'course': 2140,
#  'expect': 2841,
#  'welcome': 7863,
#  'party': 5401,
#  'lots': 4436,
#  'presents': 5711,
#  'ill': 3787,
#  'get': 3253,
#  'back': 1260,
#  'loads': 4385,
#  'love': 4447,
#  'nicky': 5037,
#  'kallis': 4083,
#  'ready': 5926,
#  'bat': 1308,
#  '2nd': 430,
#  'innings': 3861,
#  'arun': 1146,
#  'transfr': 7428,
#  'amt': 1021,
#  'short': 6471,
#  'cute': 2226,
#  'good': 3325,
#  'person': 5463,
#  'nah': 4943,
#  'dub': 2601,
#  'je': 3998,
#  'buff': 1610,
#  'wearing': 7829,
#  'fwiw': 3187,
#  'reason': 5939,
#  'around': 1134,
#  'time': 7297,
#  'smoke': 6632,
#  'gas': 3213,
#  'afford': 901,
#  'someone': 6668,
#  'tells': 7148,
#  'apparently': 1081,
#  'happens': 3481,
#  'somebody': 6666,
#  'wants': 7794,
#  'light': 4328,
#  'tried': 7447,
#  'contact': 2081,
#  '750': 659,
#  'pound': 5659,
#  'prize': 5743,
#  'claim': 1917,
#  'easy': 2640,
#  'call': 1669,
#  '087187272008': 134,
#  'now1': 5123,
#  '10p': 255,
#  'per': 5449,
#  'minute': 4755,
#  'btnationalrate': 1600,
#  'dude': 2604,
#  'ive': 3960,
#  'seeing': 6336,
#  'lotta': 4438,
#  'corvettes': 2118,
#  'lately': 4241,
#  'ha': 3439,
#  'popped': 5629,
#  'loo': 4413,
#  'helloed': 3546,
#  'hello': 3544,
#  'long': 4410,
#  'quit': 5858,
#  'like': 4332,
#  'minutes': 4756,
#  'day': 2284,
#  'think': 7240,
#  'chennai': 1855,
#  'well': 7865,
#  'settled': 6391,
#  'waiting': 7766,
#  'bus': 1628,
#  'inform': 3848,
#  'ever': 2793,
#  'list': 4361,
#  'buyers': 1640,
#  'geeeee': 3235,
#  'internet': 3889,
#  'really': 5936,
#  'bad': 1263,
#  'today': 7338,
#  'eh': 2677,
#  'wont': 7992,
#  'believe': 1365,
#  'true': 7458,
#  'incredible': 3829,
#  'txts': 7515,
#  'reply': 6051,
#  'learn': 4271,
#  'truly': 7461,
#  'amazing': 1004,
#  'things': 7239,
#  'blow': 1461,
#  'mind': 4739,
#  'o2fwd': 5169,
#  '18ptxt': 335,
#  'leave': 4274,
#  'wif': 7921,
#  'lar': 4230,
#  'ìï': 8232,
#  'wan': 7785,
#  'carry': 1749,
#  'meh': 4665,
#  'heavy': 3535,
#  'da': 2236,
#  'num': 5143,
#  '98321561': 783,
#  'familiar': 2893,
#  'want': 7790,
#  'laid': 4213,
#  'tonight': 7375,
#  'dogging': 2511,
#  'locations': 4390,
#  'sent': 6370,
#  'direct': 2452,
#  'ur': 7614,
#  'mob': 4799,
#  'join': 4027,
#  'uks': 7538,
#  'largest': 4234,
#  'network': 5012,
#  'txting': 7512,
#  'moan': 4798,
#  '69888nyt': 633,
#  'ec2a': 2646,
#  '31pmsg150p': 466,
#  'east': 2637,
#  'coast': 1969,
#  'machan': 4525,
#  'go': 3297,
#  'gym': 3436,
#  'tomorrow': 7363,
#  'wil': 7928,
#  'come': 2002,
#  'late': 4238,
#  'goodnight': 3334,
#  'tired': 7310,
#  'arguing': 1122,
#  'week': 7847,
#  'jokin': 4035,
#  'oni': 5239,
#  'busy': 1632,
#  'wun': 8064,
#  'disturb': 2480,
#  'takes': 7078,
#  'little': 4370,
#  'child': 1881,
#  'afraid': 902,
#  'dark': 2261,
#  'become': 1342,
#  'teenager': 7136,
#  'stay': 6840,
#  'station': 6837,
#  'block': 1447,
#  'away': 1237,
#  'house': 3683,
#  'youll': 8189,
#  'right': 6119,
#  'since': 6532,
#  'armenia': 1131,
#  'ends': 2719,
#  'swann': 7026,
#  'take': 7074,
#  'howard': 3689,
#  'msg': 4874,
#  'mobile': 4801,
#  'content': 2085,
#  'order': 5286,
#  'resent': 6065,
#  'previous': 5721,
#  'attempt': 1190,
#  'failed': 2880,
#  'due': 2606,
#  'error': 2758,
#  'queries': 5849,
#  'customersqueriesnetvisionukcom': 2224,
#  'aight': 943,
#  'sorry': 6702,
#  'ten': 7155,
#  'years': 8147,
#  'shower': 6486,
#  'whats': 7890,
#  'plan': 5543,
#  'hows': 3693,
#  'husband': 3740,
#  'cant': 1716,
#  'give': 3281,
#  'everything': 2803,
#  'need': 4989,
#  'actually': 860,
#  'could': 2130,
#  'better': 1390,
#  'yor': 8182,
#  'ownyouve': 5339,
#  'got': 3348,
#  'money': 4828,
#  'work': 8005,
#  'man': 4567,
#  'pay': 5424,
#  'rent': 6037,
#  'even': 2787,
#  'fill': 2971,
#  'fucking': 3165,
#  'tank': 7094,
#  'yes': 8155,
#  'stressed': 6901,
#  'depressed': 2369,
#  'didnt': 2418,
#  'thanksgiving': 7194,
#  'cuz': 2231,
#  'tell': 7145,
#  'nothing': 5111,
#  'private': 5741,
#  '2004': 368,
#  'account': 836,
#  'statement': 6836,
#  '07742676969': 25,
#  'shows': 6492,
#  '786': 665,
#  'unredeemed': 7584,
#  'bonus': 1481,
#  'points': 5601,
#  '08719180248': 144,
#  'identifier': 3769,
#  'code': 1977,
#  '45239': 535,
#  'expires': 2851,
#  'ok': 5212,
#  'later': 4243,
#  'find': 2983,
#  'lucky': 4485,
#  'told': 7353,
#  'earlier': 2625,
#  'pple': 5668,
#  'finish': 2990,
#  'way': 7821,
#  'toshiba': 7398,
#  'portege': 5634,
#  'm100': 4509,
#  'gd': 3229,
#  'otherwise': 5304,
#  'part': 5392,
#  'job': 4019,
#  'natuition': 4967,
#  'entered': 2736,
#  'cabin': 1656,
#  'pa': 5345,
#  'said': 6224,
#  'happy': 3486,
#  'bday': 1333,
#  'boss': 1501,
#  'felt': 2944,
#  'special': 6741,
#  'askd': 1158,
#  'lunch': 4491,
#  'invited': 3904,
#  'apartment': 1071,
#  'yeah': 8144,
#  'basically': 1304,
#  'next': 5027,
#  'mom': 4820,
#  'amp': 1016,
#  'please': 5562,
#  'ltgt': 4478,
#  'dollar': 2521,
#  'loan': 4386,
#  'mid': 4723,
#  'february': 2934,
#  'pls': 5570,
#  'trying': 7468,
#  'figure': 2967,
#  'suppose': 7003,
#  'see': 6334,
#  'couple': 2137,
#  'different': 2432,
#  'people': 5447,
#  'wed': 7839,
#  'together': 7347,
#  'set': 6387,
#  'dates': 2275,
#  'dont': 2529,
#  'watch': 7807,
#  'men': 4683,
#  'haha': 3445,
#  'alivebetter': 977,
#  'correct': 2114,
#  'looking': 4418,
#  'confirmed': 2061,
#  'staying': 6843,
#  'weekend': 7848,
#  'lol': 4405,
#  'try': 7467,
#  'send': 6359,
#  'warned': 7797,
#  'sprint': 6793,
#  'dead': 2295,
#  'slow': 6607,
#  'prolly': 5773,
#  'month': 4834,
#  'remember': 6020,
#  'spell': 6751,
#  'name': 4947,
#  'naughty': 4971,
#  'make': 4557,
#  'wet': 7883,
#  'forwarded': 3094,
#  '21870000hi': 380,
#  'mailbox': 4551,
#  'messaging': 4711,
#  'sms': 6637,
#  'alert': 964,
#  '40': 509,
#  'matches': 4611,
#  '09056242159': 163,
#  'retrieve': 6097,
#  'messages': 4707,
#  'cc100pmin': 1777,
#  'gonna': 3323,
#  'head': 3514,
#  'usf': 7632,
#  'fifteen': 2960,
#  'message': 4702,
#  'ignoring': 3780,
#  'shopping': 6466,
#  'promise': 5776,
#  'care': 1729,
#  'princess': 5732,
#  'run': 6199,
#  'pics': 5509,
#  'chance': 1807,
#  'ttyl': 7478,
#  'heart': 3526,
#  'empty': 2712,
#  'without': 7961,
#  'wisdom': 7950,
#  'eyes': 2870,
#  'dreams': 2566,
#  'life': 4318,
#  'frnds': 3149,
#  'alwys': 1003,
#  'touch': 7403,
#  'sweet': 7033,
#  'yup': 8214,
#  'going': 3313,
#  'bahamas': 1270,
#  'callfreefone': 1687,
#  '08081560665': 52,
#  'speak': 6739,
#  'live': 4371,
#  'operator': 5263,
#  'either': 2682,
#  'cruise': 2186,
#  'ofå': 5204,
#  '2000': 365,
#  'cash': 1755,
#  '18only': 334,
#  'opt': 5273,
#  'txt': 7507,
#  '07786200117': 27,
#  'would': 8031,
#  'despite': 2383,
#  'cramps': 2155,
#  'girl': 3274,
#  'login': 4399,
#  'dat': 2271,
#  'dad': 2239,
#  'fetching': 2949,
#  'youre': 8193,
#  'car': 1724,
#  'hour': 3681,
#  'half': 3455,
#  'apeshit': 1073,
#  'dear': 2303,
#  'sirsalam': 6547,
#  'alaikkumpride': 958,
#  'pleasure': 5565,
#  'meeting': 4660,
#  'tea': 7121,
#  'shopwe': 6468,
#  'pleased': 5563,
#  'number': 5144,
#  'qatarrakhesh': 5840,
#  'indianpls': 3837,
#  'save': 6268,
#  'numberrespectful': 5146,
#  'regards': 5997,
#  'win': 7933,
#  '100': 238,
#  'music': 4920,
#  'gift': 3266,
#  'vouchers': 7739,
#  'every': 2794,
#  'starting': 6830,
#  'draw': 2560,
#  '87066': 737,
#  'tscs': 7472,
#  'wwwldewcom': 8078,
#  'skillgame1winaweek': 6570,
#  'age16150ppermesssubscription': 917,
#  'yo': 8178,
#  'pick': 5505,
#  'something': 6674,
#  'else': 2695,
#  'dunno': 2613,
#  'lei': 4288,
#  'shd': 6430,
#  'driving': 2580,
#  'lor': 4424,
#  'sch': 6287,
#  'hr': 3698,
#  'birth': 1419,
#  '8lb': 767,
#  '7oz': 673,
#  'mother': 4851,
#  'brilliantly': 1568,
#  'able': 808,
#  'fridayhope': 3135,
#  'alternativehope': 1000,
#  'yr': 8205,
#  'terms': 7164,
#  'oic': 5209,
#  'saw': 6272,
#  'tot': 7399,
#  'din': 2442,
#  'found': 3097,
#  'group': 3401,
#  'liao': 4307,
#  'realise': 5930,
#  'guy': 3431,
#  'bother': 1504,
#  'exams': 2823,
#  'outta': 5323,
#  'cars': 1750,
#  'gr8': 3361,
#  'okay': 5213,
#  'soon': 6692,
#  'best': 1382,
#  'hm': 3614,
#  'morning': 4846,
#  'headache': 3515,
#  'anyone': 1060,
#  'hurry': 3736,
#  'soup': 6720,
#  'done': 2526,
#  'also': 997,
#  'beads': 1335,
#  'thinking': 7243,
#  'thanks': 7192,
#  'sending': 6362,
#  'mental': 4686,
#  'ability': 805,
#  'question': 5851,
#  'temales': 7151,
#  'wonderful': 7989,
#  'thank': 7191,
#  'great': 3381,
#  'borrow': 1500,
#  'bag': 1267,
#  'might': 4727,
#  'ax': 1241,
#  '07734396839': 24,
#  'ibh': 3753,
#  'customer': 2222,
#  'loyalty': 4466,
#  'offer': 5189,
#  'new': 5020,
#  'nokia6600': 5081,
#  '10': 237,
#  'txtauctiontxt': 7510,
#  'wordstart': 8004,
#  'no81151': 5064,
#  'now4t': 5124,
#  'wonders': 7991,
#  'world': 8011,
#  '7th': 677,
#  '6th': 648,
#  'style': 6936,
#  '5th': 603,
#  'smile': 6625,
#  '4th': 563,
#  'personality': 5466,
#  '3rd': 498,
#  'nature': 4969,
#  '1st': 354,
#  'lovely': 4451,
#  'friendship': 3143,
#  'spook': 6779,
#  'halloween': 3460,
#  'collection': 1990,
#  'logo': 4400,
#  'pic': 5504,
#  'plus': 5576,
#  'free': 3112,
#  'eerie': 2662,
#  'tone': 7367,
#  'card': 1725,
#  '8007': 682,
#  'zed': 8220,
#  '08701417012150p': 67,
#  'logopic': 4403,
#  'lazy': 4259,
#  'type': 7519,
#  'forgot': 3083,
#  'lect': 4277,
#  'pouch': 5658,
#  'nice': 5033,
#  'hot': 3676,
#  'fantasies': 2902,
#  '08707509020': 80,
#  '20p': 375,
#  'min': 4736,
#  'ntt': 5138,
#  'ltd': 4473,
#  'po': 5581,
#  'box': 1515,
#  '1327': 285,
#  'croydon': 2184,
#  'cr9': 2152,
#  '5wb': 604,
#  '0870': 62,
#  'national': 4964,
#  'rate': 5902,
#  'straight': 6894,
#  'bring': 1570,
#  'bud': 1605,
#  'drinks': 2576,
#  'useful': 7630,
#  'played': 5553,
#  'smash': 6618,
#  'bros': 1581,
#  'religiously': 6013,
#  'leaving': 4276,
#  'congrats': 2065,
#  'school': 6289,
#  'wat': 7806,
#  'plans': 5550,
#  'hoping': 3664,
#  'langport': 4224,
#  'town': 7409,
#  'anytime': 1068,
#  'babes': 1253,
#  'hope': 3657,
#  'shit': 6450,
#  'nights': 5045,
#  'sleep': 6585,
#  'fell': 2943,
#  'asleep': 1164,
#  '5iåõm': 594,
#  'knackered': 4166,
#  'iåõm': 3967,
#  'dreading': 2563,
#  'thou': 7257,
#  'upto': 7611,
#  'know': 4171,
#  'shall': 6418,
#  'may': 4631,
#  'dice': 2413,
#  'art': 1143,
#  'class': 1925,
#  'thru': 7274,
#  'though': 7258,
#  'idea': 3765,
#  'taka': 7073,
#  'look': 4414,
#  'us': 7624,
#  'sounds': 6718,
#  'lot': 4433,
#  'spent': 6756,
#  'chastity': 1830,
#  'device': 2398,
#  'boy': 1530,
#  'grins': 3393,
#  'beatings': 1338,
#  'dog': 2507,
#  'lounge': 4443,
#  'bath': 1311,
#  'crave': 2160,
#  'miss': 4765,
#  'ahmad': 935,
#  'saeed': 6220,
#  'al': 957,
#  'hallaq': 3459,
#  'cool': 2104,
#  'liked': 4333,
#  'photos': 5499,
#  'sexy': 6400,
#  '08712402972': 99,
#  'immediately': 3798,
#  'urgent': 7617,
#  'fakemy': 2885,
#  'thts': 7277,
#  'reffering': 5986,
#  'uif': 7533,
#  'member': 4676,
#  'wit': 7958,
#  'mail': 4550,
#  'link': 4352,
#  'vl': 7726,
#  'credited': 2169,
#  'rs': 6181,
#  'il': 3785,
#  'getiing': 3255,
#  'rsi': 6183,
#  'acc': 821,
#  'wen': 7870,
#  'goes': 3309,
#  'fuck': 3162,
#  'woke': 7981,
#  'dropped': 2584,
#  'cell': 1789,
#  'stairs': 6815,
#  'seems': 6341,
#  'alright': 993,
#  'phews': 5486,
#  'entry': 2746,
#  '250': 391,
#  'weekly': 7850,
#  'competition': 2024,
#  'text': 7175,
#  '80086': 684,
#  '18': 330,
#  'tc': 7115,
#  'wwwtxttowincouk': 8103,
#  'plz': 5578,
#  'lt3': 4472,
#  'news': 5024,
#  'hassling': 3498,
#  'weed': 7845,
#  'andres': 1031,
#  'haughaighgtujhyguj': 3502,
#  '515pm': 580,
#  'taunton': 7108,
#  '4mths': 556,
#  'price': 5724,
#  'orange': 5281,
#  'line': 4345,
#  'rental': 6038,
#  'latest': 4244,
#  'camera': 1700,
#  'phones': 5496,
#  '11mths': 268,
#  'mobilesdirect': 4803,
#  '08000938767': 43,
#  'update': 7596,
#  'or2stoptxt': 5279,
#  'unsubscribe': 7589,
#  'yet': 8169,
#  'package': 5347,
#  'term': 7162,
#  '54': 585,
#  'weeks': 7851,
#  'resubmit': 6090,
#  'request': 6058,
#  'expiry': 2852,
#  'themob': 7216,
#  'help': 3550,
#  'info': 3846,
#  'dizzamn': 2486,
#  'ask': 1157,
#  'suitemates': 6971,
#  'macho': 4528,
#  'range': 5898,
#  'used': 7629,
#  'interfued': 3887,
#  'blackberry': 1430,
#  'bold': 1475,
#  'bb': 1317,
#  'em': 2698,
#  'olowoyey': 5230,
#  'uscedu': 7627,
#  'argentina': 1119,
#  'sad': 6218,
#  'secretary': 6326,
#  'blessing': 1444,
#  'daal': 2237,
#  'auction': 1200,
#  'brand': 1542,
#  'nokia': 5079,
#  '7250': 653,
#  '86021': 730,
#  'hgsuite3422lands': 3580,
#  'roww1j6hl': 6173,
#  'teach': 7122,
#  'ship': 6445,
#  'turns': 7492,
#  'randomlly': 5894,
#  'within': 7960,
#  '5min': 596,
#  'opening': 5260,
#  'youve': 8199,
#  'year': 8146,
#  'wishin': 7955,
#  'jays': 3994,
#  'getting': 3260,
#  'impatient': 3801,
#  'belligerent': 1369,
#  'accidant': 827,
#  'tookplace': 7382,
#  'somewhere': 6680,
#  'ghodbandar': 3263,
#  'rd': 5915,
#  'traffic': 7416,
#  'moves': 4863,
#  'slovely': 6606,
#  'slip': 6599,
#  'worry': 8020,
#  'important': 3803,
#  'dislikes': 2475,
#  'bed': 1345,
#  '09066612661': 219,
#  'landline': 4220,
#  '5000': 574,
#  'luxury': 4500,
#  'canary': 1707,
#  'islands': 3930,
#  'holiday': 3636,
#  'await': 1232,
#  'tcs': 7117,
#  'sae': 6219,
#  'award': 1235,
#  '20m12aq': 374,
#  '150ppm': 310,
#  '16': 325,
#  'ûï': 8236,
#  'left': 4280,
#  'dessert': 2384,
#  'suntec': 6989,
#  'textbuddy': 7179,
#  'chat': 1831,
#  'horny': 3667,
#  'guys': 3432,
#  'area': 1115,
#  '25p': 394,
#  'receive': 5952,
#  'search': 6317,
#  'postcode': 5649,
#  'gaytextbuddycom': 3221,
#  '89693': 761,
#  'mag': 4541,
#  'avo': 1230,
#  'point': 5600,
#  'kkcongratulation': 4156,
#  'sun': 6980,
#  'anti': 1056,
#  'medicine': 4653,
#  'address': 869,
#  'sir': 6543,
#  'turned': 7490,
#  'green': 3387,
#  'meant': 4646,
#  'friend': 3139,
#  'wanted': 7792,
#  'worth': 8026,
#  'say': 6273,
#  'normal': 5099,
#  'panic': 5366,
#  'tuesday': 7481,
#  'guess': 3421,
#  'last': 4235,
#  'phasing': 5484,
#  'fourth': 3099,
#  'dimension': 2441,
#  'idk': 3771,
#  'keep': 4104,
#  'saying': 6275,
#  'moved': 4862,
#  'butting': 1636,
#  'heads': 3517,
#  'freedom': 3114,
#  'vs': 7742,
#  'responsibility': 6081,
#  'much': 4892,
#  'deal': 2297,
#  'barely': 1296,
#  'keeping': 4105,
#  'gets': 3257,
#  'added': 865,
#  'sheffield': 6433,
#  'tom': 7357,
#  'air': 945,
#  'opinions': 5265,
#  'categories': 1768,
#  'measure': 4649,
#  'ethnicity': 2776,
#  'census': 1790,
#  'transcribing': 7423,
#  'solve': 6663,
#  'case': 1754,
#  'murdered': 4916,
#  'ltdecimalgt': 4474,
#  'afternoon': 907,
#  '1his': 343,
#  'wife': 7922,
#  'called': 1683,
#  'police': 5606,
#  '2police': 438,
#  'questioned': 5852,
#  'everyone': 2800,
#  '3wife': 504,
#  'siri': 6544,
#  'sleeping': 6587,
#  'murder': 4915,
#  'took': 7381,
#  'place': 5537,
#  '4cook': 545,
#  'cooking': 2103,
#  '5gardener': 591,
#  'picking': 5507,
#  'vegetables': 7677,
#  '6housemaid': 640,
#  'post': 5646,
#  'office': 5194,
#  '7children': 670,
#  'play': 5552,
#  '8neighbour': 769,
#  'marriage': 4598,
#  'arrested': 1138,
#  'murderer': 4917,
#  'whos': 7912,
#  'brilliant': 1566,
#  '2nights': 432,
#  'uve': 7649,
#  'xchat': 8111,
#  'wildest': 7930,
#  '86688': 734,
#  '150pmsgrcvdhgsuite3422landsroww1j6hl': 306,
#  'ldn': 4261,
#  '18yrs': 336,
#  'cinema': 1912,
#  'pass': 5405,
#  '09061209465': 177,
#  'suprman': 7005,
#  'matrix3': 4620,
#  'starwars3': 6833,
#  'etc': 2774,
#  'bx420ip45we': 1648,
#  '150pm': 301,
#  'anything': 1065,
#  'toa': 7333,
#  'payoh': 5431,
#  'walk': 7773,
#  'completely': 2032,
#  'formclark': 3089,
#  'utter': 7644,
#  'waste': 7803,
#  'chad': 1801,
#  'gymnastics': 3437,
#  'wanna': 7788,
#  'site': 6552,
#  'says': 6276,
#  'christians': 1905,
#  'full': 3172,
#  'train': 7417,
#  'northampton': 5102,
#  'skyving': 6581,
#  'ho': 3625,
#  'wednesday': 7842,
#  'fancy': 2900,
#  'comedy': 2003,
#  'club': 1957,
#  'wa': 7752,
#  'efficient': 2666,
#  'gee': 3233,
#  'thanx': 7197,
#  'plane': 5544,
#  'end': 2715,
#  'congratulations': 2066,
#  'awarded': 1236,
#  '500': 573,
#  'cd': 1779,
#  'tncs': 7332,
#  'win150ppmx3age16': 7934,
#  'random': 5893,
#  'old': 5228,
#  'roomate': 6161,
#  'campus': 1703,
#  'graduated': 3362,
#  'theoretically': 7221,
#  'agent': 920,
#  'goodies': 3330,
#  'mat': 4609,
#  '87021': 736,
#  'never': 5016,
#  'blame': 1435,
#  'days': 2289,
#  'happiness': 3485,
#  'experience': 2846,
#  'essential': 2771,
#  'gods': 3307,
#  'blessings': 1445,
#  'lemme': 4289,
#  'forward': 3093,
#  'sex': 6396,
#  'cuddling': 2204,
#  'sleeps': 6590,
#  'purpose': 5826,
#  '75000': 660,
#  'homeowners': 3643,
#  'tenants': 7156,
#  'previously': 5722,
#  'refused': 5994,
#  '0800': 38,
#  '1956669': 338,
#  'hard': 3487,
#  'step': 6853,
#  'foward': 3100,
#  'fall': 2888,
#  'ruin': 6192,
#  'close': 1946,
#  'alexs': 969,
#  'unnecessarily': 7581,
#  'affectionate': 898,
#  'loans': 4387,
#  'credit': 2168,
#  'noworriesloanscom': 5130,
#  '08717111821': 121,
#  'costa': 2122,
#  'del': 2343,
#  'sol': 6659,
#  '09050090044': 162,
#  'toclaim': 7337,
#  'pobox334': 5587,
#  'stockport': 6870,
#  'sk38xh': 6565,
#  'costå': 2127,
#  'max10mins': 4628,
#  'online': 5241,
#  'transaction': 7422,
#  'complain': 2026,
#  'onlybettr': 5245,
#  'directly': 2453,
#  'bsnl': 1596,
#  'offc': 5186,
#  'nd': 4976,
#  'apply': 1088,
#  'lunchyou': 4493,
#  'onlinewhy': 5242,
#  'hmm': 3615,
#  'already': 991,
#  'squatting': 6799,
#  'walking': 7776,
#  'oh': 5206,
#  'yah': 8130,
#  'cancel': 1708,
#  'leh': 4286,
#  'hmmbad': 3616,
#  'newshype': 5025,
#  'park': 5387,
#  'plaza': 5561,
#  '700': 651,
#  'studio': 6926,
#  'takenonly': 7077,
#  'bedrm900': 1346,
#  'ringtoneking': 6131,
#  '84484': 721,
#  'anyway': 1069,
#  'holla': 3638,
#  ...}

# %%
# How are these vectors stored?
X_test_vect[0]                  # very sparse vector
# Out:
# <1x8240 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2 stored elements in Compressed Sparse Row format>

# %%
# Can we convert the vectors to arrays?
X_test_vect[0].toarray()
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]])

# %% [markdown]
# ### Fit RandomForestClassifier On Top Of Vectors

# %%
# Fit a basic Random Forest model on these vectors
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf_model = rf.fit(X_train_vect, y_train.values.ravel())  # ravel() flattens the array

# %%
# Use the trained model to make predictions on the test data
y_pred = rf_model.predict(X_test_vect)

# %%
# Evaluate the predictions of the model on the holdout test set
from sklearn.metrics import precision_score, recall_score

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
print('Precision: {} / Recall: {} / Accuracy: {}'.format(
    round(precision, 3), round(recall, 3), round((y_pred==y_test['label']).sum()/len(y_pred), 3)))
# Out:
# Precision: 1.0 / Recall: 0.807 / Accuracy: 0.97

# %%
# 100% precision -> when it idenitfied an item it was always correct
# 80% recall -> correctly identifies 80% of the spam that exists
# 97% accuracy -> correctly identifies 97% of all items
